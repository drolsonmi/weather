# %%
from WxFunctions import *
wx = load_daily()

# %%
DailyNumbers(wx, '01-14-2026')
# Out:
# Max T            NaN
# Average T        NaN
# Min T            NaN
# Precip           0.0
# Heated Precip    0.0
# dtype: float64

# %%
WxExtremes(wx, start_date='10/01/2025', n=3)
# Out:
# ===== 10/01/2025 through 2026-01-26 =====
# --- Average Temperatures ---
# Average High: 56.46235294117647
# Average     : 41.15705882352942
# Average Low : 28.382647058823533
# --- 3 highest temperatures ---
#             Date  AirTF_Max
# 2298  2025-10-02       83.2
# 2304  2025-10-08       80.8
# 2299  2025-10-03       80.3
# --- 3 lowest temperatures ---
#             Date  AirTF_Min
# 2395  2026-01-10      10.82
# 2383  2025-12-29      11.19
# 2384  2025-12-30      13.88
# --- Accumulated Precipitation ---
# Total Liquid Precip: 2.6099999999999994
# Total Heated Precip: 3.159
# --- 3 days with highest precipitation ---
#             Date  Rain_Tot
# 2342  2025-11-16      0.42
# 2305  2025-10-09      0.37
# 2387  2026-01-02      0.36
# --- 3 days with highest heated precipitation ---
#             Date  HeatedPrecip_Tot
# 2306  2025-10-10             0.693
# 2342  2025-11-16             0.359
# 2387  2026-01-02             0.335
