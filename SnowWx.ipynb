# %%
from WxFunctions import *
wx = load_daily()
# Out:
# /home/meo/Documents/weather/WxFunctions.py:42: SyntaxWarning: invalid escape sequence '\ '
#   cmd = f'cp ./data/Snow\ Weather_Daily.dat ./data/Snow_Daily.csv'
# Running on Unix/Linux

# %%
WxExtremes(wx, start_date='01/01/2025', end_date='12/31/2025', n=3)
# Out:
# ===== 01/01/2025 through 12/31/2025 =====
# --- Average Temperatures ---
# Average High: 67.26994350282487
# Average     : 51.47584745762712
# Average Low : 36.0843615819209
# --- 3 highest temperatures ---
#             Date  AirTF_Max
# 2249  2025-08-13       98.8
# 2256  2025-08-20       98.5
# 2219  2025-07-14       98.5
# --- 3 lowest temperatures ---
#             Date  AirTF_Min
# 2052  2025-01-21     -1.041
# 2051  2025-01-20      1.409
# 2054  2025-01-23      2.879
# --- Accumulated Precipitation ---
# Total Liquid Precip: 6.18
# Total Heated Precip: 6.433
# --- 3 days with highest precipitation ---
#             Date  Rain_Tot
# 2342  2025-11-16      0.42
# 2305  2025-10-09      0.37
# 2151  2025-05-05      0.32
# --- 3 days with highest heated precipitation ---
#             Date  HeatedPrecip_Tot
# 2306  2025-10-10             0.693
# 2262  2025-08-27             0.623
# 2342  2025-11-16             0.359
