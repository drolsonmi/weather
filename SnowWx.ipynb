# %%
from WxFunctions import *
wx = load_daily()

# %%
DailyNumbers(wx, '01-14-2026')
# Out:
# Max T            NaN
# Average T        NaN
# Min T            NaN
# Precip           0.0
# Heated Precip    0.0
# dtype: float64

# %%
WxExtremes(wx, start_date='01/01/2026', n=3)
# Out:
# ===== 01/01/2026 through 2026-02-02 =====
# --- Average Temperatures ---
# Average High: 45.719677419354845
# Average     : 30.209999999999997
# Average Low : 18.377225806451612
# --- 3 highest temperatures ---
#             Date  AirTF_Max
# 2416  2026-02-01      61.85
# 2415  2026-01-31      56.24
# 2399  2026-01-15      51.72
# --- 3 lowest temperatures ---
#             Date  AirTF_Min
# 2410  2026-01-26      4.464
# 2409  2026-01-25     10.090
# 2404  2026-01-20     10.460
# --- Accumulated Precipitation ---
# Total Liquid Precip: 0.79
# Total Heated Precip: 0.7100000000000001
# --- 3 days with highest precipitation ---
#             Date  Rain_Tot
# 2387  2026-01-02      0.36
# 2386  2026-01-01      0.22
# 2390  2026-01-05      0.16
# --- 3 days with highest heated precipitation ---
#             Date  HeatedPrecip_Tot
# 2387  2026-01-02             0.335
# 2386  2026-01-01             0.217
# 2390  2026-01-05             0.122

# %%
CalendarYears(wx, enddate='01-31')
# Out:
#                     2019          2020          2021          2022  \
# Max T                NaN         45.84         48.53         39.74
# Max T Date            []  [2020-01-14]  [2021-01-29]  [2022-01-31]
# Average T            NaN     26.360645     23.135484     18.988375
# Min T                NaN         5.926        -5.329        -11.08
# Min T Date            []  [2020-01-11]  [2021-01-11]  [2022-01-02]
# Total Precip         0.0          0.66          0.37          0.15
# Max Precip           NaN          0.13          0.17          0.07
# Max Precip Date       []  [2020-01-01]  [2021-01-30]  [2022-01-08]
# Total Heated Precip  0.0         0.319          0.06         0.071
#
#                              2023          2024          2025          2026
# Max T                       52.69         57.56         55.01         56.24
# Max T Date           [2023-01-10]  [2024-01-31]  [2025-01-02]  [2026-01-31]
# ...

# %%
WxSummary(wx, '2026-01-01', '2026-01-31')
# Out:
# {'Max T': np.float64(56.24),
#  'Max T Date': array([datetime.date(2026, 1, 31)], dtype=object),
#  'Average T': np.float64(29.970666666666663),
#  'Min T': np.float64(4.464),
#  'Min T Date': array([datetime.date(2026, 1, 26)], dtype=object),
#  'Total Precip': np.float64(0.79),
#  'Max Precip': np.float64(0.36),
#  'Max Precip Date': array([datetime.date(2026, 1, 2)], dtype=object),
#  'Total Heated Precip': np.float64(0.7100000000000001)}
