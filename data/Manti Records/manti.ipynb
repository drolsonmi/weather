# %% [markdown]
# Obtain data:
# * https://www.weather.gov/wrh/Climate?wfo=slc
# * Select Manti
# * Calendar day summaries
# * Year Range: 1910 - 2025 (for 2026 numbers)
# * Select variable
#     * Max temp
#     * Min temp
#     * Avg temp
#     * Mean precip
# * Go
# * Copy data into .csv files

# %%
import numpy as np
import pandas as pd

# %%
maxT = pd.read_csv('manti_maxT_record.csv', index_col=0, header=2)
minT = pd.read_csv('manti_minT_record.csv', index_col=0, header=2)
avgT = pd.read_csv('manti_avgT_record.csv', index_col=0, header=2)
normal = pd.read_csv('manti_normal.csv', index_col=0, header=2)
